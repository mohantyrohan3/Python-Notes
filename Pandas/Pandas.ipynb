# %% [markdown]
# ### Used for Manipulating Data

# %%
#import pandas as pd
# obj_data=pd.read_csv()

# %%
import pandas as pd
obj_name=pd.read_csv("C:\\Python\\Numpy\\terrorismData.csv")
obj_name
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
df=obj_name.copy()

# %%
df.head() # Gives an idea of few entries
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (181691, 17)
# Year             int64
# Month            int64
# Day              int64
# Country         object
# State           object
# Region          object
# City            object
# Latitude       float64
# Longitude      float64
# AttackType      object
# Killed         float64
# Wounded        float64
# Target          object
# Summary         object
# Group           object
# Target_type     object
# Weapon_type     object
# dtype: object

# %%
df.columns # For changing columns values do df.columns=[" "," "]
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'State', 'Region', 'City',
#        'Latitude', 'Longitude', 'AttackType', 'Killed', 'Wounded', 'Target',
#        'Summary', 'Group', 'Target_type', 'Weapon_type'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %%
# To acess a particular column
df.Year
# Out:
# 0         1970
# 1         1970
# 2         1970
# 3         1970
# 4         1970
#           ...
# 181686    2017
# 181687    2017
# 181688    2017
# 181689    2017
# 181690    2017
# Name: Year, Length: 181691, dtype: int64

# %%
df.isnull()
df.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# State            421
# Region             0
# City             434
# Latitude        4556
# Longitude       4557
# AttackType         0
# Killed         10313
# Wounded        16311
# Target           636
# Summary        66129
# Group              0
# Target_type        0
# Weapon_type        0
# dtype: int64

# %%
# To get a slice of the data
df.iloc[1:10,1:5]
# Out:
#    Month  Day        Country       State
# 1      0    0         Mexico     Federal
# 2      1    0    Philippines      Tarlac
# 3      1    0         Greece      Attica
# 4      1    0          Japan     Fukouka
# 5      1    1  United States    Illinois
# 6      1    2        Uruguay  Montevideo
# 7      1    2  United States  California
# 8      1    2  United States   Wisconsin
# 9      1    3  United States   Wisconsin

# %% [markdown]
# ## Data Manipulation

# %%
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
a=df.drop(0)
a.head()
# Out:
#    Year  Month  Day        Country     State          Region         City  \
# 1  1970      0    0         Mexico   Federal   North America  Mexico city
# 2  1970      1    0    Philippines    Tarlac  Southeast Asia      Unknown
# 3  1970      1    0         Greece    Attica  Western Europe       Athens
# 4  1970      1    0          Japan   Fukouka       East Asia      Fukouka
# 5  1970      1    1  United States  Illinois   North America        Cairo
#
#     Latitude   Longitude                      AttackType  Killed  Wounded  \
# 1  19.371887  -99.086624     Hostage Taking (Kidnapping)     0.0      0.0
# 2  15.478598  120.599741                   Assassination     1.0      0.0
# 3  37.997490   23.762728               Bombing/Explosion     NaN      NaN
# 4  33.580412  130.396361  Facility/Infrastructure Attack     NaN      NaN
# 5  37.005105  -89.176269                   Armed Assault     0.0      0.0
#
#                       Target  \
# 1    Nadine Chaval, daughter
# ...

# %%
# its done by labeling
df.drop(1,inplace=True) # Actually deletes the row
df.head()
# Out:
#    Year  Month  Day             Country     State  \
# 0  1970      7    2  Dominican Republic       NaN
# 2  1970      1    0         Philippines    Tarlac
# 3  1970      1    0              Greece    Attica
# 4  1970      1    0               Japan   Fukouka
# 5  1970      1    1       United States  Illinois
#
#                         Region           City   Latitude   Longitude  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 2               Southeast Asia        Unknown  15.478598  120.599741
# 3               Western Europe         Athens  37.997490   23.762728
# 4                    East Asia        Fukouka  33.580412  130.396361
# 5                North America          Cairo  37.005105  -89.176269
#
#                        AttackType  Killed  Wounded                     Target  \
# 0                   Assassination     1.0      0.0               Julio Guzman
# 2                   Assassination     1.0      0.0                   Employee
# ...

# %%
df.index[0]
# df.drop(df.index[],inplace=True)
# Out:
# 0

# %%
df.Year>2000
# Out:
# 0         False
# 2         False
# 3         False
# 4         False
# 5         False
#           ...
# 181686     True
# 181687     True
# 181688     True
# 181689     True
# 181690     True
# Name: Year, Length: 181690, dtype: bool

# %%
df[df.Year>2000]
# Out:
#         Year  Month  Day      Country            State  \
# 71650   2001      1    0     Colombia  Valle del Cauca
# 71651   2001      1    1        Yemen             Adan
# 71652   2001      1    1     Colombia           Bogota
# 71653   2001      1    1       Turkey         Istanbul
# 71654   2001      1    1      Algeria           Djelfa
# ...      ...    ...  ...          ...              ...
# 181686  2017     12   31      Somalia  Middle Shebelle
# 181687  2017     12   31        Syria         Lattakia
# 181688  2017     12   31  Philippines      Maguindanao
# 181689  2017     12   31        India          Manipur
# 181690  2017     12   31  Philippines      Maguindanao
#
#                             Region             City   Latitude   Longitude  \
# 71650                South America          Unknown   3.800889  -76.641271
# 71651   Middle East & North Africa             Aden  12.825647   44.846416
# 71652                South America  Bogota district   4.598100  -74.076030
# ...

# %%
df[df.Country=="India"].describe()
# Out:
#                Year         Month           Day      Latitude     Longitude  \
# count  11960.000000  11960.000000  11960.000000  11801.000000  11801.000000
# mean    2006.248411      6.439047     15.624415     25.947957     82.788312
# std       10.096520      3.323835      8.778965      5.674857      7.039908
# min     1972.000000      1.000000      0.000000      8.169375     68.775724
# 25%     1999.000000      4.000000      8.000000     22.585272     75.341218
# 50%     2010.000000      6.000000     15.000000     25.272700     81.866144
# 75%     2014.000000      9.000000     23.000000     31.147131     88.352341
# max     2017.000000     12.000000     31.000000     34.655639     96.644737
#
#              Killed       Wounded
# count  11740.000000  11506.000000
# mean       1.647445      2.518686
# std        4.681342     11.344047
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        1.000000      1.000000
# ...

# %%
df.head()
df.iloc[0] # Its is for positions
# df.loc[0] # Its for labels
# Out:
# Year                                  1970
# Month                                    7
# Day                                      2
# Country                 Dominican Republic
# State                                  NaN
# Region         Central America & Caribbean
# City                         Santo Domingo
# Latitude                         18.456792
# Longitude                       -69.951164
# AttackType                   Assassination
# Killed                                 1.0
# Wounded                                0.0
# Target                        Julio Guzman
# Summary                                NaN
# Group                               MANO-D
# Target_type    Private Citizens & Property
# Weapon_type                        Unknown
# Name: 0, dtype: object

# %%
# To add a row
# df.loc[0]=[  No of Entries  ] It adds the row at the end of the list
df.tail()
# Out:
#         Year  Month  Day      Country            State  \
# 181686  2017     12   31      Somalia  Middle Shebelle
# 181687  2017     12   31        Syria         Lattakia
# 181688  2017     12   31  Philippines      Maguindanao
# 181689  2017     12   31        India          Manipur
# 181690  2017     12   31  Philippines      Maguindanao
#
#                             Region           City   Latitude   Longitude  \
# 181686          Sub-Saharan Africa  Ceelka Geelow   2.359673   45.385034
# 181687  Middle East & North Africa         Jableh  35.407278   35.942679
# 181688              Southeast Asia       Kubentog   6.900742  124.437908
# 181689                  South Asia         Imphal  24.798346   93.940430
# 181690              Southeast Asia  Cotabato City   7.209594  124.241966
#
#                             AttackType  Killed  Wounded            Target  \
# 181686                   Armed Assault     1.0      2.0        Checkpoint
# ...

# %%
df.index
# Out:
# Int64Index([     0,      2,      3,      4,      5,      6,      7,      8,
#                  9,     10,
#             ...
#             181681, 181682, 181683, 181684, 181685, 181686, 181687, 181688,
#             181689, 181690],
#            dtype='int64', length=181690)

# %%
df.reset_index(drop=True)
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      1    0         Philippines           Tarlac
# 2       1970      1    0              Greece           Attica
# 3       1970      1    0               Japan          Fukouka
# 4       1970      1    1       United States         Illinois
# ...      ...    ...  ...                 ...              ...
# 181685  2017     12   31             Somalia  Middle Shebelle
# 181686  2017     12   31               Syria         Lattakia
# 181687  2017     12   31         Philippines      Maguindanao
# 181688  2017     12   31               India          Manipur
# 181689  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
# How to delete column
df.drop("Year",axis=1,inplace=True)

# %%
df
# Out:
#         Month  Day             Country            State  \
# 0           7    2  Dominican Republic              NaN
# 2           1    0         Philippines           Tarlac
# 3           1    0              Greece           Attica
# 4           1    0               Japan          Fukouka
# 5           1    1       United States         Illinois
# ...       ...  ...                 ...              ...
# 181686     12   31             Somalia  Middle Shebelle
# 181687     12   31               Syria         Lattakia
# 181688     12   31         Philippines      Maguindanao
# 181689     12   31               India          Manipur
# 181690     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 2                    Southeast Asia        Unknown  15.478598  120.599741
# ...

# %%
# How to add a column
df["Totalaffected"]=df["Killed"]+df["Wounded"]
df.head()
# Out:
#    Month  Day             Country     State                       Region  \
# 0      7    2  Dominican Republic       NaN  Central America & Caribbean
# 2      1    0         Philippines    Tarlac               Southeast Asia
# 3      1    0              Greece    Attica               Western Europe
# 4      1    0               Japan   Fukouka                    East Asia
# 5      1    1       United States  Illinois                North America
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
# 5          Cairo  37.005105  -89.176269                   Armed Assault
#
#    Killed  Wounded                     Target  \
# ...

# %% [markdown]
# ## Handling Nan

# %%
# 2 options Drop Na or Fill Na
### df.dropna(inplace=True) will actually drop the rows with na values present in it then just reset the index
### Another option is we can fill all the nan with different value(mean of the entire column,median of column)
## df.year.fillna(df.year.mean(),inplace=True)

# %% [markdown]
# ## Handling Strings

# %%
## Make a function and convert the string values to integer
## def f(s):



## df["New column"]=df.oldcolumn.apply(f)



### Very Important Functions is df[""].value_counts()
## df[""].value_counts()[0:10] Its gives top 10 values
## df[""].value_counts()[].keys() gives only the keys
