# %%
import requests

res=requests.get('http://api.open-notify.org/iss-now.json')
res.status_code
# Out:
# 200

# %%
res1=requests.get('https://codingninjas.in/api/v3/events')
print(res1.headers['Content-Type'])
# Out:
# application/json

# %%
import requests

p=requests.get("https://dog.ceo/api/breeds/list/all")
print(p.status_code)
# Out:
# 200

# %%
import json

python_data=json.loads(p.text)
print(python_data)
# Out:
# {'message': {'affenpinscher': [], 'african': [], 'airedale': [], 'akita': [], 'appenzeller': [], 'australian': ['shepherd'], 'basenji': [], 'beagle': [], 'bluetick': [], 'borzoi': [], 'bouvier': [], 'boxer': [], 'brabancon': [], 'briard': [], 'buhund': ['norwegian'], 'bulldog': ['boston', 'english', 'french'], 'bullterrier': ['staffordshire'], 'cattledog': ['australian'], 'chihuahua': [], 'chow': [], 'clumber': [], 'cockapoo': [], 'collie': ['border'], 'coonhound': [], 'corgi': ['cardigan'], 'cotondetulear': [], 'dachshund': [], 'dalmatian': [], 'dane': ['great'], 'deerhound': ['scottish'], 'dhole': [], 'dingo': [], 'doberman': [], 'elkhound': ['norwegian'], 'entlebucher': [], 'eskimo': [], 'finnish': ['lapphund'], 'frise': ['bichon'], 'germanshepherd': [], 'greyhound': ['italian'], 'groenendael': [], 'havanese': [], 'hound': ['afghan', 'basset', 'blood', 'english', 'ibizan', 'plott', 'walker'], 'husky': [], 'keeshond': [], 'kelpie': [], 'komondor': [], 'kuvasz': [], 'labradoodle': [
# ...

# %%
print(python_data["message"]["hound"])
for i in python_data["message"]["hound"]:
    print(i)
# Out:
# ['afghan', 'basset', 'blood', 'english', 'ibizan', 'plott', 'walker']
# afghan
# basset
# blood
# english
# ibizan
# plott
# walker

# %%
import requests
p=requests.get("https://api.codingninjas.com/api/v3/courses")
p.status_code
# Out:
# 200

# %%
import json 
python_data=json.loads(p.text)
python_data
# Out:
# {'data': {'courses': [{'id': 6,
#     'title': 'Machine Learning',
#     'online_title': 'online-machine-learning-course',
#     'offline_title': 'classroom-machine-learning-course',
#     'name': 'Machine Learning & Deep Learning Course',
#     'level': 'Advanced Courses',
#     'brief_intro': 'Machine learning engineers build, implement, and maintain machine learning systems in technology products.',
#     'preview_image_url': 'https://ninjasfiles.s3.amazonaws.com/0000000000001181.png',
#     'available_online': True,
#     'available_offline': False,
#     'is_career_track': False,
#     'course_group_id': 2,
#     'classroom_icon_url': 'https://files.codingninjas.in/0000000000003766.png'},
#    {'id': 40,
#     'title': 'Data structures and Algorithms [C++/Java/Python]',
#     'online_title': 'premium-foundation-course',
#     'offline_title': '',
#     'name': 'Premium Data structures and Algorithms [C++/Java/Python]',
#     'level': 'Foundation Courses',
# ...

# %%
for i in python_data["data"]["courses"]:
    print(i["online_title"])
# Out:
# online-machine-learning-course
# premium-foundation-course
# premium-android-app-development-course
# online-competitive-programming-track
# premium-machine-learning-course
# premium-data-science-course
# onlline-c-plus-plus-course
# premium-competitive-course
# premium-full-stack-web-development-course
# system-design-course
# online-web-dev-with-react
# online-java-course
# online-full-stack-node-js-web-dev-course
# online-android-development-career-track
# online-data-science-course
# online-interview-preparation
# operating-system
# ninja-web-developer-career-track-mern-stack
# online-competitive-programming-course
# web-developer-career-track
# online-python-course
# data-Scientist-career-track
# online-android-Development-kotlin
# online-aptitude-preparation
# machine-learning-engineer-career-track

# %%
import requests

p=requests.get('https://api.codingninjas.com/api/v3/events?event_category=ALL_EVENTS&event_sub_category=All%20Time%20Favorites&tag_list=&offset=0&_ga=2.49336102.1241984895.1657716744-1645906495.1657465648')

p.status_code
# Out:
# 200

# %%
import json
python_data=json.loads(p.text)

# %%
ans=python_data["data"]["events"]
ans[0]["short_desc"]
# Out:
# '"INNOVATE INDIA CODING CHAMPIONSHIP"\r\n\r\nTIMELINE: 19 JUNE 2022 - 13 AUG 2022 \r\n\r\nPARTICIPATION ELIGIBILITY CRITERIA: \r\n\r\nCollege/University enrolled students: B.TECH/M.TECH/BCA/PHD  '

# %% [markdown]
# ## More Assignments

# %%
import requests
import json

p=requests.get("https://api.openaq.org/v1/cities",params={"country":"BE","order_by":"city"})
a=json.loads(p.text)
a
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': 'CC BY 4.0d',
#   'website': 'api.openaq.org',
#   'page': 1,
#   'limit': 100,
#   'found': 12},
#  'results': [{'country': 'BE',
#    'name': 'Antwerpen',
#    'city': 'Antwerpen',
#    'count': 830727,
#    'locations': 24},
#   {'country': 'BE',
#    'name': 'Brabant wallon',
#    'city': 'Brabant wallon',
#    'count': 90467,
#    'locations': 1},
#   {'country': 'BE',
#    'name': 'Brussels-Capital Region',
#    'city': 'Brussels-Capital Region',
#    'count': 531152,
#    'locations': 11},
#   {'country': 'BE',
#    'name': 'Flanders',
#    'city': 'Flanders',
#    'count': 10973,
#    'locations': 6},
#   {'country': 'BE',
#    'name': 'Hainaut',
#    'city': 'Hainaut',
#    'count': 464078,
#    'locations': 7},
#   {'country': 'BE',
#    'name': 'Liege',
#    'city': 'Liege',
#    'count': 478753,
#    'locations': 8},
#   {'country': 'BE',
#    'name': 'Limburg',
#    'city': 'Limburg',
#    'count': 142190,
# ...
